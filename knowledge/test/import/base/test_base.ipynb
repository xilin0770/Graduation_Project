# %% [markdown]
# ## 1. 测试Path使用

# %%
from pathlib import Path

pdf_path = r"D:\feiq\xiazai\20_掌柜智库项目\资料包\pdf文档\doc\hak180使用说明书.pdf"

path = Path(pdf_path)
print(path)
# Out:
# D:\feiq\xiazai\20_掌柜智库项目\资料包\pdf文档\doc\hak180使用说明书.pdf

# %%
path.suffix
# Out:
# '.pdf'

# %%
path.stem
# Out:
# 'hak180使用说明书'
